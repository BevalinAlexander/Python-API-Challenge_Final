# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies
import requests
import json
import numpy as np
import random
import time
import pandas as pd
from citipy import citipy
import matplotlib.pyplot as plt
from scipy.stats import linregress
from config_ba import weather_api_key
from pprint import pprint
from datetime import datetime

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %%
#prototype proof of concept 
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
city = "New York City"
query_url = f"{url}appid={weather_api_key}&q={city}&units={units}" 
weather_response = requests.get(query_url)
weather_json = weather_response.json()
weather_json
# Out:
# {'coord': {'lon': -74.006, 'lat': 40.7143},
#  'weather': [{'id': 800,
#    'main': 'Clear',
#    'description': 'clear sky',
#    'icon': '01d'}],
#  'base': 'stations',
#  'main': {'temp': 64.58,
#   'feels_like': 61.68,
#   'temp_min': 63,
#   'temp_max': 66.2,
#   'pressure': 1012,
#   'humidity': 20},
#  'visibility': 10000,
#  'wind': {'speed': 6.91, 'deg': 0},
#  'clouds': {'all': 1},
#  'dt': 1619907400,
#  'sys': {'type': 1,
#   'id': 4610,
#   'country': 'US',
#   'sunrise': 1619862853,
#   'sunset': 1619913106},
#  'timezone': -14400,
#  'id': 5128581,
#  'name': 'New York',
#  'cod': 200}

# %%
lon = weather_json["coord"]["lon"]
lat = weather_json["coord"]["lat"]
temp = weather_json["main"]["temp"]
humidity = weather_json["main"]["humidity"]
cloudiness = weather_json["clouds"]["all"]
wind_speed = weather_json["wind"]["speed"]
name = weather_json["name"]
print(f"The temperature is currently {temp}F. in {name}.")
print(f"The barometer is currently at {humidity}% in {name}.")
print(f"There is {cloudiness}% cloud cover currently in {name}.")
print(f"The wind is currently blowing at {wind_speed} mph in {name}.")
print(f"The latitude of {name} is {lat}.")
print(f"The longitude of {name} is {lon}.")
# Out:
# The temperature is currently 64.58F. in New York.
# The barometer is currently at 20% in New York.
# There is 1% cloud cover currently in New York.
# The wind is currently blowing at 6.91 mph in New York.
# The latitude of New York is 40.7143.
# The longitude of New York is -74.006.

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 605

# %%
cities
# Out:
# ['bulawayo',
#  'tshane',
#  'puerto ayora',
#  'hilo',
#  'qaanaaq',
#  'amderma',
#  'tazovskiy',
#  'kharan',
#  'ponta do sol',
#  'liesveld',
#  'richards bay',
#  'polunochnoye',
#  'tura',
#  'yellowknife',
#  'caceres',
#  'bluff',
#  'albany',
#  'port elizabeth',
#  'hamilton',
#  'jamestown',
#  'georgetown',
#  'avarua',
#  'meulaboh',
#  'chokurdakh',
#  'barrow',
#  'new norfolk',
#  'elizabeth city',
#  'vestmannaeyjar',
#  'lamesa',
#  'ngukurr',
#  'vaini',
#  'porbandar',
#  'quchan',
#  'mataura',
#  'kodiak',
#  'ribeira grande',
#  'talnakh',
#  'hermanus',
#  'bredasdorp',
#  'ushuaia',
#  'manta',
#  'faanui',
#  'hobart',
#  'rikitea',
#  'surovatikha',
#  'gat',
#  'sao filipe',
#  'busselton',
#  'los llanos de aridane',
#  'airai',
#  'jiddah',
#  'sukhumi',
#  'kegayli',
#  'solnechnyy',
#  'atuona',
#  'mys shmidta',
#  'litovko',
#  'kampot',
#  'uwayl',
#  'thompson',
#  'emba',
#  'oktyabrskiy',
#  'derzhavinsk',
#  'tuktoyaktuk',
#  'altamont',
#  'butaritari',
#  'chuy',
#  'kavieng',
#  'taolanaro',
#  'lavrentiya',
#  'bengkulu',
#  'kogon',
#  'pogar',
#  'mindelo',
#  'san mateo ixtatan',
#  'labuhan',
#  'illoqqortoormiut',
#  'tabarqah',
#  'saint george',
#  'saint pete beach',
#  'krasnokholm',
#  'bethel',
#  'barentsburg',
#  'longyearbyen',
#  'cayenne',
#  'hithadhoo',
#  'saint-philippe',
#  'punta arenas',
#  'maputo',
#  'yirol',
#  'baglan',
#  'kaitangata',
#  'severo-kurilsk',
#  'yaan',
#  'traverse city',
#  'lebu',
#  'ituango',
#  'chute-aux-outardes',
#  'riyadh',
#  'katsuura',
#  'santiago del estero',
#  'pevek',
#  'maykain',
#  'fortuna',
#  'nizhneyansk',
#  'nome',
#  'kapaa',
#  'podyuga',
#  'taltal',
#  'benha',
#  'vestmanna',
#  'sao miguel do iguacu',
#  'gulbarga',
#  'bambous virieux',
#  'ayna',
#  'dingle',
#  'lompoc',
#  'carnarvon',
#  'caravelas',
#  'ende',
#  'cape town',
#  'petropavlovsk-kamchatskiy',
#  'ambovombe',
#  'pucallpa',
#  'vostok',
#  'staryy nadym',
#  'guerrero negro',
#  'saldanha',
#  'maningrida',
#  'cumra',
#  'san patricio',
#  'aurillac',
#  'antigonish',
#  'belushya guba',
#  'torbay',
#  'dunedin',
#  'bathsheba',
#  'castro',
#  'upernavik',
#  'santa vitoria',
#  'totana',
#  'lincoln',
#  'nikolskoye',
#  'necochea',
#  'yulara',
#  'nelson bay',
#  'phrai bung',
#  'mbandaka',
#  'boa vista',
#  'rawson',
#  'port hedland',
#  'port alfred',
#  'xining',
#  'narsaq',
#  'sumenep',
#  'asau',
#  'sinnamary',
#  'port lincoln',
#  'izhma',
#  'ixtapa',
#  'shitanjing',
#  'hunza',
#  'bouna',
#  'victoria',
#  'verkhoyansk',
#  'marsh harbour',
#  'cajamarca',
#  'mastic beach',
#  'faya',
#  'lodja',
#  'neftekumsk',
#  'manokwari',
#  'takestan',
#  'kungurtug',
#  'tasiilaq',
#  'tautira',
#  'mehamn',
#  'berlevag',
#  'tsihombe',
#  'ancud',
#  'pitimbu',
#  'constitucion',
#  'aleksandrov gay',
#  'attawapiskat',
#  'yuryev-polskiy',
#  'danielskuil',
#  'palmer',
#  'gariaband',
#  'pacific grove',
#  'port keats',
#  'banda aceh',
#  'itarema',
#  'mount isa',
#  'keizer',
#  'viligili',
#  'voh',
#  'noshiro',
#  'khash',
#  'atar',
#  'parabel',
#  'penzance',
#  'cidreira',
#  'ahuimanu',
#  'verkh-chebula',
#  'champerico',
#  'bargal',
#  'souillac',
#  'kautokeino',
#  'saint-augustin',
#  'coahuayana',
#  'healdsburg',
#  'sipe sipe',
#  'mahebourg',
#  'adrar',
#  'matagami',
#  'nhulunbuy',
#  'broome',
#  'san quintin',
#  'eenhana',
#  'san jose',
#  'oistins',
#  'athabasca',
#  'khatanga',
#  'manaus',
#  'emirdag',
#  'gazojak',
#  'praia da vitoria',
#  'aplahoue',
#  'suamico',
#  'yerbogachen',
#  'nara',
#  'gobabis',
#  'arraial do cabo',
#  'pontes e lacerda',
#  'marsa matruh',
#  'jadu',
#  'saint-francois',
#  'namibe',
#  'da lat',
#  'naze',
#  'murray bridge',
#  'terrace',
#  'hovd',
#  'chippewa falls',
#  'port blair',
#  'turbat',
#  'mezhdurechensk',
#  'daru',
#  'wawa',
#  'buchanan',
#  'lagoa',
#  'arnissa',
#  'samarai',
#  'namatanai',
#  'thinadhoo',
#  'yayva',
#  'corowa',
#  'pisco',
#  'mayumba',
#  'altay',
#  'roblin',
#  'sampit',
#  'korla',
#  'mao',
#  'limbang',
#  'alofi',
#  'prince rupert',
#  'elena',
#  'parrsboro',
#  'honiara',
#  'porto santo',
#  'lerwick',
#  'aloleng',
#  'chara',
#  'irbeyskoye',
#  'kerouane',
#  'zlatoustovsk',
#  'kamaishi',
#  'aquiraz',
#  'opuwo',
#  'kirov',
#  'taoudenni',
#  'nanortalik',
#  'aitape',
#  'gravdal',
#  'vardo',
#  'buraydah',
#  'takoradi',
#  'phalaborwa',
#  'auki',
#  'rongcheng',
#  'bamako',
#  'saleaula',
#  'san cristobal',
#  'saskylakh',
#  'quatre cocos',
#  'mahadday weyne',
#  'maneromango',
#  'lorengau',
#  'el balyana',
#  'satipo',
#  'yumen',
#  'cherskiy',
#  'popova',
#  'crotone',
#  'aklavik',
#  'santa rosa',
#  'manicore',
#  'huaicheng',
#  'ijaki',
#  'plettenberg bay',
#  'ipixuna',
#  'paamiut',
#  'kruisfontein',
#  'ayan',
#  'rio grande',
#  'camana',
#  'abu kamal',
#  'energeticheskiy',
#  'yeppoon',
#  'hasaki',
#  'bazarnyye mataki',
#  'hay river',
#  'ilulissat',
#  'la ronge',
#  'sao joao da barra',
#  'tihuatlan',
#  'norman wells',
#  'pangnirtung',
#  'umba',
#  'san isidro',
#  'oranjemund',
#  'inhambane',
#  'linkou',
#  'tumannyy',
#  'doctor juan leon mallorquin',
#  'tiksi',
#  'vila franca do campo',
#  'pangoa',
#  'longyan',
#  'portland',
#  'sudislavl',
#  'srednekolymsk',
#  'gazanjyk',
#  'waipawa',
#  'leningradskiy',
#  'tual',
#  'caranavi',
#  'roche-la-moliere',
#  'magadan',
#  'grand river south east',
#  'kamenka',
#  'sao jose da coroa grande',
#  'mar del plata',
#  'boyolangu',
#  'husavik',
#  'sangar',
#  'umzimvubu',
#  'parsabad',
#  'tuatapere',
#  'chumikan',
#  'tupik',
#  'kemalpasa',
#  'coetupo',
#  'egvekinot',
#  'potsdam',
#  'dhidhdhoo',
#  'khormuj',
#  'clyde river',
#  'khovu-aksy',
#  'cutervo',
#  'east london',
#  'riverton',
#  'olafsvik',
#  'illapel',
#  'vaitupu',
#  'kijang',
#  'evensk',
#  'morant bay',
#  'mendahara',
#  'acarau',
#  'uvalde',
#  'isangel',
#  'cockburn town',
#  'blackwater',
#  'deputatskiy',
#  'tumbagaan',
#  'novopskov',
#  'sudzha',
#  'piedras negras',
#  'salvador',
#  'pringsewu',
#  'te anau',
#  'bandarbeyla',
#  'palabuhanratu',
#  'belen',
#  'vila velha',
#  'vanimo',
#  'tver',
#  'mahon',
#  'olden',
#  'waddan',
#  'kalmunai',
#  'dakar',
#  'champasak',
#  'kaeo',
#  'ulaanbaatar',
#  'sahrak',
#  'ocean city',
#  'veraval',
#  'bunia',
#  'burnie',
#  'payakumbuh',
#  'hualmay',
#  'whitehorse',
#  'manikganj',
#  'nurota',
#  'dikson',
#  'matara',
#  'college',
#  'varadero',
#  'suntar',
#  'lianran',
#  'port hardy',
#  'abu samrah',
#  'celestun',
#  'quelimane',
#  'tucurui',
#  'dauphin',
#  'opelousas',
#  'rome',
#  'saint-pierre',
#  'cap malheureux',
#  'tabiauea',
#  'fevralsk',
#  'kaka',
#  'umm lajj',
#  'akdepe',
#  'kahului',
#  'kavaratti',
#  'cizre',
#  'batagay-alyta',
#  'aksarka',
#  'hambantota',
#  'half moon bay',
#  'mount gambier',
#  'pochutla',
#  'vao',
#  'vuktyl',
#  'yorosso',
#  'panguipulli',
#  'itacare',
#  'esna',
#  'pakwach',
#  'tezu',
#  'kemijarvi',
#  'cabedelo',
#  'planaltina',
#  'kalmar',
#  'tucuma',
#  'comodoro rivadavia',
#  'baturaja',
#  'genhe',
#  'bastia',
#  'gay',
#  'santa fe',
#  'amahai',
#  'pitkyaranta',
#  'ust-ishim',
#  'balkanabat',
#  'hofn',
#  'kazalinsk',
#  'carutapera',
#  'strezhevoy',
#  'zhanaozen',
#  'buta',
#  'cabo san lucas',
#  'tomatlan',
#  'highland springs',
#  'sandviken',
#  'oranzherei',
#  'tuni',
#  'boyuibe',
#  'higuey',
#  'belyy yar',
#  'camacha',
#  'zhoucun',
#  'biak',
#  'tokur',
#  'sabang',
#  'klaksvik',
#  'najran',
#  'road town',
#  'puerto asis',
#  'nemuro',
#  'valentin gomez farias',
#  'ruteng',
#  'birjand',
#  'san rafael',
#  'pasinler',
#  'ziro',
#  'micheweni',
#  'jackson',
#  'gavle',
#  'fort-shevchenko',
#  'iqaluit',
#  'waingapu',
#  'port moresby',
#  'alghero',
#  'provideniya',
#  'mantua',
#  'sioux lookout',
#  'bontang',
#  'malwan',
#  'saint-georges',
#  'grindavik',
#  'nangomba',
#  'luancheng',
#  'inderborskiy',
#  'ahipara',
#  'tingo maria',
#  'ambilobe',
#  'canutama',
#  'coquimbo',
#  'hachinohe',
#  'russkaya polyana',
#  'tarauaca',
#  'sistranda',
#  'linden',
#  'shache',
#  'esperance',
#  'chaguani',
#  'maamba',
#  'tashtyp',
#  'saint-joseph',
#  'maicao',
#  'constantine',
#  'haines junction',
#  'biloela',
#  'campoverde',
#  'isiro',
#  'nioro',
#  'skwierzyna',
#  'muzquiz',
#  'yongan',
#  'almaznyy',
#  'doha',
#  'rapid valley',
#  'zdvinsk',
#  'san ramon',
#  'mosquera',
#  'port augusta',
#  'conceicao do araguaia',
#  'kolyvan',
#  'samusu',
#  'rosarito',
#  'bilibino',
#  'port-gentil',
#  'muli',
#  'shkotovo-26',
#  'enshi',
#  'sabha',
#  'lahat',
#  'broken hill',
#  'rundu',
#  'vetluga',
#  'coihaique',
#  'le portel',
#  'havre-saint-pierre',
#  'ornskoldsvik',
#  'askarovo',
#  'alice springs',
#  'lermontovka',
#  'codrington',
#  'bagdarin',
#  'fairbanks',
#  'choctaw',
#  'alexandria',
#  'joniskis',
#  'jinxiang',
#  'tutoia',
#  'harper',
#  'trelew',
#  'lieto',
#  'leirvik',
#  'jaisalmer',
#  'kurmanayevka',
#  'rehoboth',
#  'gweta',
#  'okandja',
#  'olinda',
#  'nalut',
#  'sulangan',
#  'san juan',
#  'rantoul',
#  'jammalamadugu',
#  'duluth',
#  'maragogi',
#  'bolshoye ignatovo',
#  'salalah',
#  'andros',
#  'bubaque',
#  'labutta',
#  'charters towers',
#  'buala']

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
#Define empty lists to store values
cloudiness = []
country = []
date = []
max_temp = []
humidity = []
lat = []
lng = []
wind_speed = []
city_name = []

#Looping through cities to make api calls using city as query
i = 1
for city in cities:
    city=city
#     query_url = url + "appid=" + weather_api_key + "&q=" + city
    query_url = f"{url}appid={weather_api_key}&q={city}&units={units}" 
    response = requests.get(query_url).json()
    
#Extracting data. Missing data is handled by try and except  
    try:
        cloudiness.append(response["clouds"]["all"])
        country.append(response["sys"]["country"])
        date.append(response["dt"])
        max_temp.append(response["main"]['temp_max'])
        humidity.append(response["main"]['humidity'])
        lat.append(response["coord"]["lat"])  
        lng.append(response["coord"]["lon"])
        wind_speed.append(response["wind"]["speed"])
        city_name.append(response["name"])
        print(f"Processing record {i}|{city}")
        i+=1
    except (KeyError):
        print("City not found. skipping.")
# Out:
# Processing record 1|bulawayo
# Processing record 2|tshane
# Processing record 3|puerto ayora
# Processing record 4|hilo
# Processing record 5|qaanaaq
# City not found. skipping.
# Processing record 6|tazovskiy
# Processing record 7|kharan
# Processing record 8|ponta do sol
# Processing record 9|liesveld
# Processing record 10|richards bay
# Processing record 11|polunochnoye
# Processing record 12|tura
# Processing record 13|yellowknife
# Processing record 14|caceres
# Processing record 15|bluff
# Processing record 16|albany
# Processing record 17|port elizabeth
# Processing record 18|hamilton
# Processing record 19|jamestown
# Processing record 20|georgetown
# Processing record 21|avarua
# Processing record 22|meulaboh
# Processing record 23|chokurdakh
# Processing record 24|barrow
# Processing record 25|new norfolk
# Processing record 26|elizabeth city
# Processing record 27|vestmannaeyjar
# Processing record 28|lamesa
# City not found. skipping.
# Processing record 29|vaini
# Processing record 30|porbandar
# Processing record 31|quchan
# Processing record 32|mataura
# Processing record 33|kodiak
# Processing record 34|ribeira grande
# Processing record 35|talnakh
# Processing record 36|hermanus
# Processing record 37|bredasdorp
# Processing record 38|ushuaia
# Processing record 39|manta
# Processing record 40|faanui
# Processing record 41|hobart
# Processing record 42|rikitea
# Processing record 43|surovatikha
# Processing record 44|gat
# Processing record 45|sao filipe
# Processing record 46|busselton
# Processing record 47|los llanos de aridane
# Processing record 48|airai
# City not found. skipping.
# Processing record 49|sukhumi
# City not found. skipping.
# Processing record 50|solnechnyy
# Processing record 51|atuona
# City not found. skipping.
# Processing record 52|litovko
# Processing record 53|kampot
# City not found. skipping.
# Processing record 54|thompson
# Processing record 55|emba
# Processing record 56|oktyabrskiy
# Processing record 57|derzhavinsk
# Processing record 58|tuktoyaktuk
# Processing record 59|altamont
# Processing record 60|butaritari
# Processing record 61|chuy
# Processing record 62|kavieng
# City not found. skipping.
# Processing record 63|lavrentiya
# Processing record 64|bengkulu
# Processing record 65|kogon
# Processing record 66|pogar
# Processing record 67|mindelo
# Processing record 68|san mateo ixtatan
# Processing record 69|labuhan
# City not found. skipping.
# City not found. skipping.
# Processing record 70|saint george
# Processing record 71|saint pete beach
# Processing record 72|krasnokholm
# Processing record 73|bethel
# City not found. skipping.
# Processing record 74|longyearbyen
# Processing record 75|cayenne
# Processing record 76|hithadhoo
# Processing record 77|saint-philippe
# Processing record 78|punta arenas
# Processing record 79|maputo
# City not found. skipping.
# Processing record 80|baglan
# Processing record 81|kaitangata
# Processing record 82|severo-kurilsk
# Processing record 83|yaan
# Processing record 84|traverse city
# Processing record 85|lebu
# Processing record 86|ituango
# Processing record 87|chute-aux-outardes
# Processing record 88|riyadh
# Processing record 89|katsuura
# Processing record 90|santiago del estero
# Processing record 91|pevek
# City not found. skipping.
# Processing record 92|fortuna
# City not found. skipping.
# Processing record 93|nome
# Processing record 94|kapaa
# Processing record 95|podyuga
# Processing record 96|taltal
# City not found. skipping.
# Processing record 97|vestmanna
# Processing record 98|sao miguel do iguacu
# Processing record 99|gulbarga
# Processing record 100|bambous virieux
# Processing record 101|ayna
# Processing record 102|dingle
# Processing record 103|lompoc
# Processing record 104|carnarvon
# Processing record 105|caravelas
# Processing record 106|ende
# Processing record 107|cape town
# Processing record 108|petropavlovsk-kamchatskiy
# Processing record 109|ambovombe
# Processing record 110|pucallpa
# Processing record 111|vostok
# Processing record 112|staryy nadym
# Processing record 113|guerrero negro
# Processing record 114|saldanha
# Processing record 115|maningrida
# Processing record 116|cumra
# Processing record 117|san patricio
# Processing record 118|aurillac
# Processing record 119|antigonish
# City not found. skipping.
# Processing record 120|torbay
# Processing record 121|dunedin
# Processing record 122|bathsheba
# Processing record 123|castro
# Processing record 124|upernavik
# Processing record 125|santa vitoria
# Processing record 126|totana
# Processing record 127|lincoln
# Processing record 128|nikolskoye
# Processing record 129|necochea
# Processing record 130|yulara
# Processing record 131|nelson bay
# City not found. skipping.
# Processing record 132|mbandaka
# Processing record 133|boa vista
# Processing record 134|rawson
# Processing record 135|port hedland
# Processing record 136|port alfred
# Processing record 137|xining
# Processing record 138|narsaq
# Processing record 139|sumenep
# Processing record 140|asau
# Processing record 141|sinnamary
# Processing record 142|port lincoln
# Processing record 143|izhma
# Processing record 144|ixtapa
# Processing record 145|shitanjing
# City not found. skipping.
# Processing record 146|bouna
# Processing record 147|victoria
# Processing record 148|verkhoyansk
# Processing record 149|marsh harbour
# Processing record 150|cajamarca
# Processing record 151|mastic beach
# Processing record 152|faya
# Processing record 153|lodja
# Processing record 154|neftekumsk
# Processing record 155|manokwari
# Processing record 156|takestan
# Processing record 157|kungurtug
# Processing record 158|tasiilaq
# Processing record 159|tautira
# Processing record 160|mehamn
# Processing record 161|berlevag
# City not found. skipping.
# Processing record 162|ancud
# Processing record 163|pitimbu
# Processing record 164|constitucion
# Processing record 165|aleksandrov gay
# City not found. skipping.
# Processing record 166|yuryev-polskiy
# Processing record 167|danielskuil
# Processing record 168|palmer
# Processing record 169|gariaband
# Processing record 170|pacific grove
# Processing record 171|port keats
# Processing record 172|banda aceh
# Processing record 173|itarema
# Processing record 174|mount isa
# Processing record 175|keizer
# City not found. skipping.
# Processing record 176|voh
# Processing record 177|noshiro
# Processing record 178|khash
# Processing record 179|atar
# Processing record 180|parabel
# Processing record 181|penzance
# Processing record 182|cidreira
# Processing record 183|ahuimanu
# Processing record 184|verkh-chebula
# Processing record 185|champerico
# City not found. skipping.
# Processing record 186|souillac
# Processing record 187|kautokeino
# Processing record 188|saint-augustin
# Processing record 189|coahuayana
# Processing record 190|healdsburg
# Processing record 191|sipe sipe
# Processing record 192|mahebourg
# Processing record 193|adrar
# Processing record 194|matagami
# Processing record 195|nhulunbuy
# Processing record 196|broome
# Processing record 197|san quintin
# Processing record 198|eenhana
# Processing record 199|san jose
# Processing record 200|oistins
# Processing record 201|athabasca
# Processing record 202|khatanga
# Processing record 203|manaus
# Processing record 204|emirdag
# Processing record 205|gazojak
# Processing record 206|praia da vitoria
# Processing record 207|aplahoue
# Processing record 208|suamico
# Processing record 209|yerbogachen
# Processing record 210|nara
# Processing record 211|gobabis
# Processing record 212|arraial do cabo
# Processing record 213|pontes e lacerda
# Processing record 214|marsa matruh
# Processing record 215|jadu
# Processing record 216|saint-francois
# Processing record 217|namibe
# Processing record 218|da lat
# Processing record 219|naze
# Processing record 220|murray bridge
# Processing record 221|terrace
# Processing record 222|hovd
# Processing record 223|chippewa falls
# Processing record 224|port blair
# Processing record 225|turbat
# Processing record 226|mezhdurechensk
# Processing record 227|daru
# Processing record 228|wawa
# Processing record 229|buchanan
# Processing record 230|lagoa
# Processing record 231|arnissa
# Processing record 232|samarai
# Processing record 233|namatanai
# Processing record 234|thinadhoo
# Processing record 235|yayva
# Processing record 236|corowa
# Processing record 237|pisco
# Processing record 238|mayumba
# Processing record 239|altay
# Processing record 240|roblin
# Processing record 241|sampit
# Processing record 242|korla
# Processing record 243|mao
# Processing record 244|limbang
# Processing record 245|alofi
# Processing record 246|prince rupert
# Processing record 247|elena
# Processing record 248|parrsboro
# Processing record 249|honiara
# Processing record 250|porto santo
# Processing record 251|lerwick
# Processing record 252|aloleng
# Processing record 253|chara
# Processing record 254|irbeyskoye
# Processing record 255|kerouane
# City not found. skipping.
# Processing record 256|kamaishi
# Processing record 257|aquiraz
# Processing record 258|opuwo
# Processing record 259|kirov
# Processing record 260|taoudenni
# Processing record 261|nanortalik
# Processing record 262|aitape
# Processing record 263|gravdal
# Processing record 264|vardo
# Processing record 265|buraydah
# Processing record 266|takoradi
# Processing record 267|phalaborwa
# Processing record 268|auki
# Processing record 269|rongcheng
# Processing record 270|bamako
# City not found. skipping.
# Processing record 271|san cristobal
# Processing record 272|saskylakh
# Processing record 273|quatre cocos
# City not found. skipping.
# Processing record 274|maneromango
# Processing record 275|lorengau
# City not found. skipping.
# Processing record 276|satipo
# Processing record 277|yumen
# Processing record 278|cherskiy
# Processing record 279|popova
# Processing record 280|crotone
# Processing record 281|aklavik
# Processing record 282|santa rosa
# Processing record 283|manicore
# Processing record 284|huaicheng
# City not found. skipping.
# Processing record 285|plettenberg bay
# Processing record 286|ipixuna
# Processing record 287|paamiut
# Processing record 288|kruisfontein
# Processing record 289|ayan
# Processing record 290|rio grande
# Processing record 291|camana
# Processing record 292|abu kamal
# Processing record 293|energeticheskiy
# Processing record 294|yeppoon
# Processing record 295|hasaki
# Processing record 296|bazarnyye mataki
# Processing record 297|hay river
# Processing record 298|ilulissat
# Processing record 299|la ronge
# Processing record 300|sao joao da barra
# Processing record 301|tihuatlan
# Processing record 302|norman wells
# Processing record 303|pangnirtung
# Processing record 304|umba
# Processing record 305|san isidro
# Processing record 306|oranjemund
# Processing record 307|inhambane
# Processing record 308|linkou
# City not found. skipping.
# Processing record 309|doctor juan leon mallorquin
# Processing record 310|tiksi
# Processing record 311|vila franca do campo
# Processing record 312|pangoa
# Processing record 313|longyan
# Processing record 314|portland
# Processing record 315|sudislavl
# Processing record 316|srednekolymsk
# Processing record 317|gazanjyk
# Processing record 318|waipawa
# Processing record 319|leningradskiy
# Processing record 320|tual
# Processing record 321|caranavi
# Processing record 322|roche-la-moliere
# Processing record 323|magadan
# City not found. skipping.
# Processing record 324|kamenka
# Processing record 325|sao jose da coroa grande
# Processing record 326|mar del plata
# Processing record 327|boyolangu
# Processing record 328|husavik
# Processing record 329|sangar
# City not found. skipping.
# Processing record 330|parsabad
# Processing record 331|tuatapere
# Processing record 332|chumikan
# Processing record 333|tupik
# Processing record 334|kemalpasa
# City not found. skipping.
# Processing record 335|egvekinot
# Processing record 336|potsdam
# Processing record 337|dhidhdhoo
# City not found. skipping.
# Processing record 338|clyde river
# Processing record 339|khovu-aksy
# Processing record 340|cutervo
# Processing record 341|east london
# Processing record 342|riverton
# Processing record 343|olafsvik
# Processing record 344|illapel
# City not found. skipping.
# Processing record 345|kijang
# Processing record 346|evensk
# Processing record 347|morant bay
# City not found. skipping.
# Processing record 348|acarau
# Processing record 349|uvalde
# Processing record 350|isangel
# Processing record 351|cockburn town
# Processing record 352|blackwater
# Processing record 353|deputatskiy
# Processing record 354|tumbagaan
# Processing record 355|novopskov
# Processing record 356|sudzha
# Processing record 357|piedras negras
# Processing record 358|salvador
# Processing record 359|pringsewu
# Processing record 360|te anau
# Processing record 361|bandarbeyla
# City not found. skipping.
# Processing record 362|belen
# Processing record 363|vila velha
# Processing record 364|vanimo
# Processing record 365|tver
# Processing record 366|mahon
# Processing record 367|olden
# Processing record 368|waddan
# Processing record 369|kalmunai
# Processing record 370|dakar
# Processing record 371|champasak
# Processing record 372|kaeo
# Processing record 373|ulaanbaatar
# City not found. skipping.
# Processing record 374|ocean city
# Processing record 375|veraval
# Processing record 376|bunia
# Processing record 377|burnie
# Processing record 378|payakumbuh
# Processing record 379|hualmay
# Processing record 380|whitehorse
# Processing record 381|manikganj
# Processing record 382|nurota
# Processing record 383|dikson
# Processing record 384|matara
# Processing record 385|college
# Processing record 386|varadero
# Processing record 387|suntar
# Processing record 388|lianran
# Processing record 389|port hardy
# Processing record 390|abu samrah
# Processing record 391|celestun
# Processing record 392|quelimane
# Processing record 393|tucurui
# Processing record 394|dauphin
# Processing record 395|opelousas
# Processing record 396|rome
# Processing record 397|saint-pierre
# Processing record 398|cap malheureux
# City not found. skipping.
# City not found. skipping.
# Processing record 399|kaka
# Processing record 400|umm lajj
# Processing record 401|akdepe
# Processing record 402|kahului
# Processing record 403|kavaratti
# Processing record 404|cizre
# Processing record 405|batagay-alyta
# Processing record 406|aksarka
# Processing record 407|hambantota
# Processing record 408|half moon bay
# Processing record 409|mount gambier
# Processing record 410|pochutla
# Processing record 411|vao
# Processing record 412|vuktyl
# Processing record 413|yorosso
# Processing record 414|panguipulli
# Processing record 415|itacare
# Processing record 416|esna
# City not found. skipping.
# Processing record 417|tezu
# Processing record 418|kemijarvi
# Processing record 419|cabedelo
# Processing record 420|planaltina
# Processing record 421|kalmar
# Processing record 422|tucuma
# Processing record 423|comodoro rivadavia
# Processing record 424|baturaja
# Processing record 425|genhe
# Processing record 426|bastia
# Processing record 427|gay
# Processing record 428|santa fe
# Processing record 429|amahai
# Processing record 430|pitkyaranta
# Processing record 431|ust-ishim
# Processing record 432|balkanabat
# Processing record 433|hofn
# City not found. skipping.
# Processing record 434|carutapera
# Processing record 435|strezhevoy
# Processing record 436|zhanaozen
# Processing record 437|buta
# Processing record 438|cabo san lucas
# Processing record 439|tomatlan
# Processing record 440|highland springs
# Processing record 441|sandviken
# Processing record 442|oranzherei
# Processing record 443|tuni
# Processing record 444|boyuibe
# City not found. skipping.
# Processing record 445|belyy yar
# Processing record 446|camacha
# Processing record 447|zhoucun
# Processing record 448|biak
# Processing record 449|tokur
# Processing record 450|sabang
# Processing record 451|klaksvik
# Processing record 452|najran
# Processing record 453|road town
# Processing record 454|puerto asis
# Processing record 455|nemuro
# Processing record 456|valentin gomez farias
# Processing record 457|ruteng
# Processing record 458|birjand
# Processing record 459|san rafael
# Processing record 460|pasinler
# Processing record 461|ziro
# Processing record 462|micheweni
# Processing record 463|jackson
# Processing record 464|gavle
# Processing record 465|fort-shevchenko
# Processing record 466|iqaluit
# Processing record 467|waingapu
# Processing record 468|port moresby
# Processing record 469|alghero
# Processing record 470|provideniya
# Processing record 471|mantua
# Processing record 472|sioux lookout
# Processing record 473|bontang
# City not found. skipping.
# Processing record 474|saint-georges
# Processing record 475|grindavik
# Processing record 476|nangomba
# Processing record 477|luancheng
# City not found. skipping.
# Processing record 478|ahipara
# Processing record 479|tingo maria
# Processing record 480|ambilobe
# Processing record 481|canutama
# Processing record 482|coquimbo
# Processing record 483|hachinohe
# Processing record 484|russkaya polyana
# Processing record 485|tarauaca
# Processing record 486|sistranda
# Processing record 487|linden
# Processing record 488|shache
# Processing record 489|esperance
# Processing record 490|chaguani
# Processing record 491|maamba
# Processing record 492|tashtyp
# Processing record 493|saint-joseph
# Processing record 494|maicao
# Processing record 495|constantine
# Processing record 496|haines junction
# Processing record 497|biloela
# Processing record 498|campoverde
# Processing record 499|isiro
# Processing record 500|nioro
# Processing record 501|skwierzyna
# City not found. skipping.
# Processing record 502|yongan
# Processing record 503|almaznyy
# Processing record 504|doha
# Processing record 505|rapid valley
# Processing record 506|zdvinsk
# Processing record 507|san ramon
# Processing record 508|mosquera
# Processing record 509|port augusta
# Processing record 510|conceicao do araguaia
# Processing record 511|kolyvan
# City not found. skipping.
# Processing record 512|rosarito
# Processing record 513|bilibino
# Processing record 514|port-gentil
# Processing record 515|muli
# City not found. skipping.
# Processing record 516|enshi
# Processing record 517|sabha
# Processing record 518|lahat
# Processing record 519|broken hill
# Processing record 520|rundu
# Processing record 521|vetluga
# Processing record 522|coihaique
# Processing record 523|le portel
# Processing record 524|havre-saint-pierre
# Processing record 525|ornskoldsvik
# Processing record 526|askarovo
# Processing record 527|alice springs
# Processing record 528|lermontovka
# Processing record 529|codrington
# Processing record 530|bagdarin
# Processing record 531|fairbanks
# Processing record 532|choctaw
# Processing record 533|alexandria
# Processing record 534|joniskis
# Processing record 535|jinxiang
# Processing record 536|tutoia
# Processing record 537|harper
# Processing record 538|trelew
# Processing record 539|lieto
# Processing record 540|leirvik
# Processing record 541|jaisalmer
# Processing record 542|kurmanayevka
# Processing record 543|rehoboth
# Processing record 544|gweta
# City not found. skipping.
# Processing record 545|olinda
# Processing record 546|nalut
# Processing record 547|sulangan
# Processing record 548|san juan
# Processing record 549|rantoul
# Processing record 550|jammalamadugu
# Processing record 551|duluth
# Processing record 552|maragogi
# City not found. skipping.
# Processing record 553|salalah
# Processing record 554|andros
# Processing record 555|bubaque
# City not found. skipping.
# Processing record 556|charters towers
# Processing record 557|buala

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
pprint(response)
# Out:
# {'base': 'stations',
#  'clouds': {'all': 100},
#  'cod': 200,
#  'coord': {'lat': -8.145, 'lon': 159.5921},
#  'dt': 1619907827,
#  'id': 2109528,
#  'main': {'feels_like': 88,
#           'grnd_level': 1009,
#           'humidity': 74,
#           'pressure': 1012,
#           'sea_level': 1012,
#           'temp': 82.31,
#           'temp_max': 82.31,
#           'temp_min': 82.31},
#  'name': 'Buala',
#  'sys': {'country': 'SB', 'sunrise': 1619897044, 'sunset': 1619939584},
#  'timezone': 39600,
#  'visibility': 10000,
#  'weather': [{'description': 'overcast clouds',
#               'icon': '04d',
#               'id': 804,
#               'main': 'Clouds'}],
#  'wind': {'deg': 46, 'gust': 3.96, 'speed': 2.89}}

# %%
city_data_df = pd.DataFrame(
                {'City':city_name,
                 'Latitude': lat,
                 'Longitude': lng,
                 'Temperature (max)': max_temp,
                 'Humidity': humidity,
                 'Cloudiness': cloudiness,
                 'Wind Speed': wind_speed,
                 'Country': country,
                 'Date': date
                    
                
                }
)

# %%
#export to .csv
city_data_df.to_csv("../output_data_file.csv", index = False)

# %%
city_data_df.head()
# Out:
#            City  Latitude  Longitude  Temperature (max)  Humidity  Cloudiness  \
# 0      Bulawayo  -20.1500    28.5833              57.67        85          99
# 1        Tshane  -24.0196    21.8684              56.39        35           0
# 2  Puerto Ayora   -0.7393   -90.3518              82.40        65           0
# 3          Hilo   19.7297  -155.0900              82.40        57           1
# 4       Qaanaaq   77.4840   -69.3632              33.82        68          79
#
#    Wind Speed Country        Date
# 0       15.59      ZW  1619907609
# 1        9.10      BW  1619907610
# 2       13.80      EC  1619907610
# 3        9.22      US  1619907401
# 4        5.32      GL  1619907315

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_df.describe()
# Out:
#          Latitude   Longitude  Temperature (max)    Humidity  Cloudiness  \
# count  557.000000  557.000000         557.000000  557.000000  557.000000
# mean    20.145278   17.740586          61.197756   69.698384   53.542190
# std     33.388250   89.442806          18.611173   21.789763   38.898971
# min    -54.800000 -179.166700          11.460000    3.000000    0.000000
# 25%     -8.161400  -63.598600          47.410000   58.000000   11.000000
# 50%     25.519800   24.933300          64.710000   74.000000   66.000000
# 75%     48.826400   93.600000          77.000000   87.000000   90.000000
# max     78.218600  178.416700          91.720000  100.000000  100.000000
#
#        Wind Speed          Date
# count  557.000000  5.570000e+02
# mean     7.630144  1.619908e+09
# std      5.360655  9.327184e+01
# min      0.400000  1.619907e+09
# 25%      3.440000  1.619908e+09
# 50%      6.240000  1.619908e+09
# 75%     10.360000  1.619908e+09
# max     37.980000  1.619908e+09

# %%
#  Get the indices of cities that have humidity over 100%.
# skip, no cities over 100%

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
# skip, no cities over 100%

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
#Converting Date for title of plot
timestamp = city_data_df["Date"][0]
converted_timestamp = datetime.utcfromtimestamp(timestamp)
shortened_timestamp = datetime.date(converted_timestamp)

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Temperature (max)'], marker="o", facecolors="purple", edgecolors="black",
            alpha=0.75)

plt.title(f"Latitude vs. Temperature ({shortened_timestamp})")
plt.xlabel("Latitude")
plt.ylabel("Max Temp")
plt.savefig("/Users/Akeyrar/Desktop/Data Analysis Homework /Python-API-Challenge_Final/output_data/latitude_vs_temp.png", bbox_inches="tight")

plt.show()

# %%
#The Latitude vs Temperature scatter plot is analyzing temperatures relative to latitide, showing that there is a high temperature for those cities that are closest to the equator.
#But as you move further away from the equator the temperature begins to decrease getting colder.

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Humidity'], marker="o", facecolors="purple", edgecolors="black",
            alpha=0.75)

plt.title(f"Latitude vs. Humidity ({shortened_timestamp})")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.savefig("/Users/Akeyrar/Desktop/Data Analysis Homework /Python-API-Challenge_Final/output_data/latitude_vs_humidity.png", bbox_inches="tight")

plt.show()

# %%
#The Latitude vs. Humidity scatter plot shown above is analyzing humidity relative to latitide. 
#The scatter plot shows that humidity is distributed fairly throughout the plot. Which means humidity is similar in cities that are both close and far from the equator.

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Cloudiness'], marker="o", facecolors="purple", edgecolors="black",
            alpha=0.75)

plt.title(f"Latitude vs. Cloudiness ({shortened_timestamp})")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness")
plt.savefig("/Users/Akeyrar/Desktop/Data Analysis Homework /Python-API-Challenge_Final/output_data/latitude_vs_cloudiness.png", bbox_inches="tight")

plt.show()

# %%
#The Latitude vs cloudiness scatter plot is analyzing cloudiness relative to latitide.
#From the plot above the data is showing that there is an evenly distributed data which means that there is no difference between cloudiness when cities are located far from the equator or when they are located close to the equator.

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
plt.scatter(city_data_df['Latitude'], city_data_df['Wind Speed'], marker="o", facecolors="purple", edgecolors="black",
            alpha=0.75)

plt.title(f"City Latitude vs. Wind Speed ({shortened_timestamp})")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.savefig("/Users/Akeyrar/Desktop/Data Analysis Homework /Python-API-Challenge_Final/output_data/latitude_vs_windspeed.png", bbox_inches="tight")

plt.show()

# %%
#The Latitude vs windspeed scatter plot is analyzing windspeed relative to latitide
#According to the scatter plot there is lower wind speed when the cities are closer to the equator however the wind speed increase for the cities farther from the equator.

# %% [markdown]
# ## Linear Regression

# %%
n_hemi = city_data_df.loc[city_data_df['Latitude'] > 0]
n_hemi
# Out:
#               City  Latitude  Longitude  Temperature (max)  Humidity  \
# 3             Hilo   19.7297  -155.0900              82.40        57
# 4          Qaanaaq   77.4840   -69.3632              33.82        68
# 5         Tazovsky   67.4667    78.7000              28.74        86
# 6           Kharan   28.5833    65.4167              76.86        37
# 7     Ponta do Sol   32.6667   -17.1000              57.99        66
# ..             ...       ...        ...                ...       ...
# 549  Jammalamadugu   14.8333    78.4000              80.35        73
# 550         Duluth   46.7833   -92.1066              84.20        13
# 552        Salalah   17.0151    54.0924              84.20        79
# 553         Andros   37.8333    24.9333              69.01        41
# 554        Bubaque   11.2833   -15.8333              78.75        71
#
#      Cloudiness  Wind Speed Country        Date
# 3             1        9.22      US  1619907401
# 4            79        5.32      GL  1619907315
# 5           100        2.80      RU  1619907611
# 6           100        3.98      PK  1619907611
# 7            87        1.99      PT  1619907612
# ..          ...         ...     ...         ...
# 549           2        7.61      IN  1619907824
# 550           1       21.85      US  1619907664
# 552          40        3.44      OM  1619907719
# 553          89       10.45      GR  1619907826
# 554          20       19.95      GW  1619907826
#
# [374 rows x 9 columns]

# %%
s_hemi = city_data_df.loc[city_data_df['Latitude'] < 0]
s_hemi
# Out:
#                 City  Latitude  Longitude  Temperature (max)  Humidity  \
# 0           Bulawayo  -20.1500    28.5833              57.67        85
# 1             Tshane  -24.0196    21.8684              56.39        35
# 2       Puerto Ayora   -0.7393   -90.3518              82.40        65
# 9       Richards Bay  -28.7830    32.0377              62.80        87
# 14             Bluff  -46.6000   168.3333              51.01        81
# ..               ...       ...        ...                ...       ...
# 544           Olinda   -8.0089   -34.8553              71.60        94
# 547         San Juan  -31.5375   -68.5364              72.86        34
# 551         Maragogi   -9.0122   -35.2225              76.91        86
# 555  Charters Towers  -20.1000   146.2667              66.97        77
# 556            Buala   -8.1450   159.5921              82.31        74
#
#      Cloudiness  Wind Speed Country        Date
# 0            99       15.59      ZW  1619907609
# 1             0        9.10      BW  1619907610
# 2             0       13.80      EC  1619907610
# 9            41        4.72      ZA  1619907613
# 14           57        4.00      NZ  1619907615
# ..          ...         ...     ...         ...
# 544          90        8.05      BR  1619907822
# 547          93       10.65      AR  1619907824
# 551          97        9.44      BR  1619907825
# 555           1        9.01      AU  1619907827
# 556         100        2.89      SB  1619907827
#
# [183 rows x 9 columns]

# %%
n_hemi.describe()
# Out:
#          Latitude   Longitude  Temperature (max)    Humidity  Cloudiness  \
# count  374.000000  374.000000         374.000000  374.000000  374.000000
# mean    39.876405   12.115901          57.320160   66.457219   55.213904
# std     19.603676   86.341050          20.488094   23.507161   38.603535
# min      0.048700 -179.166700          11.460000    3.000000    0.000000
# 25%     25.288375  -68.485625          39.200000   51.000000   18.500000
# 50%     40.560150   26.141650          59.000000   72.000000   71.000000
# 75%     55.254000   80.076475          77.245000   86.000000   91.750000
# max     78.218600  178.416700          91.720000  100.000000  100.000000
#
#        Wind Speed          Date
# count  374.000000  3.740000e+02
# mean     8.295267  1.619908e+09
# std      5.799326  9.356171e+01
# min      0.780000  1.619907e+09
# 25%      3.537500  1.619908e+09
# 50%      6.845000  1.619908e+09
# 75%     11.500000  1.619908e+09
# max     37.980000  1.619908e+09

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = n_hemi['Latitude']
y_values = n_hemi['Temperature (max)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(6,10),fontsize=20,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.8611705286338935

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = s_hemi['Latitude']
y_values = s_hemi['Temperature (max)']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-18,40),fontsize=12,color="red")
plt.xlabel('Latitude')
plt.ylabel('Max Temp')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.798157923273307

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = n_hemi['Latitude']
y_values = n_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(53,10),fontsize=10,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.08144435663229611

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = s_hemi['Latitude']
y_values = s_hemi['Humidity']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=14,color="red")
plt.xlabel('Latitude')
plt.ylabel('Humidity %')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.2368748354161137

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = n_hemi['Latitude']
y_values = n_hemi['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(82,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.14242838240505842

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = s_hemi['Latitude']
y_values = s_hemi['Cloudiness']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Cloudiness %')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.24044462279030826

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = n_hemi['Latitude']
y_values = n_hemi['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(82,20),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed mph')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: 0.02085028235095394

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = s_hemi['Latitude']
y_values = s_hemi['Wind Speed']
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,40),fontsize=15,color="red")
plt.xlabel('Latitude')
plt.ylabel('Wind Speed mph')
print(f"The r-squared is: {rvalue}")
plt.show()
# Out:
# The r-squared is: -0.23019163342461393
